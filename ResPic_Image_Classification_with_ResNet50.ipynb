# %% [markdown]
# # **ResPic: Image Classification with ResNet50 📷🔍**

# %% [markdown]
# ### **📷🔍 Classify images with ease using ResPic! Harness the visual superpowers of ResNet50 and unlock the potential of image classification. 🚀**

# %% [markdown]
# ![RESPIC.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Importing the Required Libraries**

# %%
# libraries and module
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %% [markdown]
# # **ResNet50 - PreTrained - Model - Image - Classification**

# %%
# model object for prediction
model = ResNet50(weights = 'imagenet')
# Out:
# ...
# 102967424/102967424 [==============================] - 5s 0us/step

# %% [markdown]
# # **Image - Preprocessing - & - Image Classifications - Using - ResNet50**

# %%
# image preprocessing pen
img_path = '/content/pen.jpg'
img = image.load_img(img_path, target_size=(224, 224))
X = image.img_to_array(img)
X = np.expand_dims(X, axis = 0)
X = preprocess_input(X)

# %%
# image prediction pen
img_pred = model.predict(X)
print("Predictions : ", decode_predictions(img_pred, top=5)[0])
# Out:
# 1/1 [==============================] - 0s 221ms/step
# Predictions :  [('n02783161', 'ballpoint', 0.95289814), ('n03388183', 'fountain_pen', 0.03011545), ('n03658185', 'letter_opener', 0.005172207), ('n03876231', 'paintbrush', 0.0039401026), ('n04033901', 'quill', 0.0019107534)]

# %%
# image preprocessing cup
img_path = '/content/cup.jpg'
img = image.load_img(img_path, target_size=(224, 224))
X = image.img_to_array(img)
X = np.expand_dims(X, axis = 0)
X = preprocess_input(X)

# %%
# image prediction cup
img_pred = model.predict(X)
print("Predictions : ", decode_predictions(img_pred, top=5)[0])
# Out:
# 1/1 [==============================] - 0s 230ms/step
# Predictions :  [('n03950228', 'pitcher', 0.3605784), ('n04560804', 'water_jug', 0.27908176), ('n07930864', 'cup', 0.1714477), ('n03063599', 'coffee_mug', 0.13156752), ('n04579145', 'whiskey_jug', 0.016968355)]

# %%
# image preprocessing cat
img_path = '/content/cat.jpg'
img = image.load_img(img_path, target_size=(224, 224))
X = image.img_to_array(img)
X = np.expand_dims(X, axis = 0)
X = preprocess_input(X)

# %%
# image prediction cat
img_pred = model.predict(X)
print("Predictions : ", decode_predictions(img_pred, top=5)[0])
# Out:
# 1/1 [==============================] - 0s 199ms/step
# Predictions :  [('n02123394', 'Persian_cat', 0.4696516), ('n02123045', 'tabby', 0.16614437), ('n02124075', 'Egyptian_cat', 0.038905773), ('n02328150', 'Angora', 0.037209284), ('n03325584', 'feather_boa', 0.025203224)]

# %% [markdown]
# # **Thanks for Reading and Visiting my Notebook**
